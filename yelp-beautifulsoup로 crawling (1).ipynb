# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json
import re
import numpy as np

# %%
review_f = pd.DataFrame(columns=[
            "user_name",
            "user_review_number",
            "review",
            "rating",
            ])

review_uf= pd.DataFrame(columns=[
            "user_name",
            "user_review_number",
            "review",
            "rating",
            ])

# %% [markdown]
# crawling 방법
# 1. sanfrancisco에 있는 restaurant 50개의 이름을 긁어온다.
# items = 20
# for item in items:
# item +=20
# response = requests.get("https://www.yelp.com/biz/hey-cookie-san-francisco?start={query}".format(query=items))
# 2. 각각의 restaurant에 있는 review, reviewer_id, reviewer_friends, number_of_review, reviewer_href를 긁어온다.
# 3. reviewer_href로 reviewer의 review,review_date,star_rate을 긁는다.

# %%
#restaurant href 50개를 긁어온다. 
item=0
df_restaurant_raw = pd.DataFrame(columns=["restaurant_href"])
for item in range(5):
    item = item* 10
    
    
    response_1= requests.get("https://www.yelp.com/search?find_loc=San+Francisco,+CA&start={query}&cflt=restaurants".format(query=item))
    restaurant= BeautifulSoup(response_1.content, "html.parser")
    restaurant_elements=restaurant.select('a.biz-name')
#     print(restaurant_elements)
    for restaurant_element in restaurant_elements:
        
        df_restaurant_raw.loc[len(df_restaurant_raw)]=[restaurant_element]
df_restaurant_raw
df_restaurant_raw.to_csv("df_restaurant_raw.csv")

# %%
df_restaurnat_raw= pd.DataFrame.from_csv("df_restaurant_raw.csv")

# %%
href_df = pd.DataFrame(columns=["restaurant_href"])
    
for numbers in range(0,55):
    href_numbers = df_restaurant_raw.restaurant_href[numbers].get('href')
    href_df.loc[len(href_df)] = [href_numbers]

new_href_df=href_df.drop([0,11,22,33,44])
#new_href_df

new_href_df.index=range(0,50)
# Out:
#                                      restaurant_href
# 0  <a class="biz-name" data-hovercard-id="2tG6Wx0...
# 1  <a class="biz-name" data-hovercard-id="rYjsxKi...
# 2  <a class="biz-name" data-hovercard-id="e1ch41L...
# 3  <a class="biz-name" data-hovercard-id="7CBA0uO...
# 4  <a class="biz-name" data-hovercard-id="4eaMLBN...

# %%
#new_href_df.to_csv("restaurant_href_df.csv")

# %%
restaurant_href_df= pd.DataFrame.from_csv("restaurant_href_df.csv")

# %%
restaurant_href_df["restaurant_url"] = restaurant_href_df["restaurant_href"].apply(
    lambda x : "https://www.yelp.com{item}".format(item=x)
    )
restaurant_href_df.head()
# Out:
#                               restaurant_href  \
# 0             /biz/j%C5%AB-ni-san-francisco-5
# 1          /biz/the-fine-mousse-san-francisco
# 2             /biz/starboard-sf-san-francisco
# 3  /biz/brasserie-saint-james-san-francisco-2
# 4                /biz/matador-san-francisco-2
#
#                                       restaurant_url
# 0  https://www.yelp.com/biz/j%C5%AB-ni-san-franci...
# 1  https://www.yelp.com/biz/the-fine-mousse-san-f...
# 2  https://www.yelp.com/biz/starboard-sf-san-fran...
# 3  https://www.yelp.com/biz/brasserie-saint-james...
# 4   https://www.yelp.com/biz/matador-san-francisco-2

# %%
# real_restaurant_url=pd.DataFrame(restaurant_href_df["restaurant_url"])
# real_restaurant_url.to_csv("real_restaurant_url.csv")
real_restaurant_url= pd.DataFrame.from_csv("real_restaurant_url.csv")

# %%
real_restaurant_url["restaurant_url1"]= real_restaurant_url["restaurant_url"].apply(
    lambda x : "{item}?start=20".format(item=x)
    )
real_restaurant_url
# Out:
#                                        restaurant_url  \
# 0   https://www.yelp.com/biz/j%C5%AB-ni-san-franci...
# 1   https://www.yelp.com/biz/the-fine-mousse-san-f...
# 2   https://www.yelp.com/biz/starboard-sf-san-fran...
# 3   https://www.yelp.com/biz/brasserie-saint-james...
# 4    https://www.yelp.com/biz/matador-san-francisco-2
# 5   https://www.yelp.com/biz/gold-dust-lounge-san-...
# 6      https://www.yelp.com/biz/hogwash-san-francisco
# 7    https://www.yelp.com/biz/the-house-san-francisco
# 8   https://www.yelp.com/biz/the-spice-jar-san-fra...
# 9    https://www.yelp.com/biz/marlowe-san-francisco-2
# 10  https://www.yelp.com/biz/the-codmother-fish-an...
# 11  https://www.yelp.com/biz/chez-maman-san-franci...
# 12  https://www.yelp.com/biz/the-chairman-san-fran...
# 13        https://www.yelp.com/biz/so-san-francisco-4
# 14  https://www.yelp.com/biz/fog-harbor-fish-house...
# 15  https://www.yelp.com/biz/rove-kitchen-san-fran...
# ...

# %%
real_restaurant_url.to_csv("restaurant_url.csv") # real_restaurant_url에다가 추가 url 넣은 표 만들어줌.

# %%
restaurant_url_add = pd.DataFrame.from_csv("restaurant_url_add.csv")

# %%
# Out:
#                                        restaurant_url
# 0   https://www.yelp.com/biz/j%C5%AB-ni-san-franci...
# 1   https://www.yelp.com/biz/the-fine-mousse-san-f...
# 2   https://www.yelp.com/biz/starboard-sf-san-fran...
# 3   https://www.yelp.com/biz/brasserie-saint-james...
# 4    https://www.yelp.com/biz/matador-san-francisco-2
# 5   https://www.yelp.com/biz/gold-dust-lounge-san-...
# 6      https://www.yelp.com/biz/hogwash-san-francisco
# 7    https://www.yelp.com/biz/the-house-san-francisco
# 8   https://www.yelp.com/biz/the-spice-jar-san-fra...
# 9    https://www.yelp.com/biz/marlowe-san-francisco-2
# 10  https://www.yelp.com/biz/the-codmother-fish-an...
# 11  https://www.yelp.com/biz/chez-maman-san-franci...
# 12  https://www.yelp.com/biz/the-chairman-san-fran...
# 13        https://www.yelp.com/biz/so-san-francisco-4
# 14  https://www.yelp.com/biz/fog-harbor-fish-house...
# 15  https://www.yelp.com/biz/rove-kitchen-san-fran...
# ...

# %%
restaurant_url_df.head()
# Out:
#                                       restaurant_url
# 0  https://www.yelp.com/biz/j%C5%AB-ni-san-franci...
# 1  https://www.yelp.com/biz/the-fine-mousse-san-f...
# 2  https://www.yelp.com/biz/starboard-sf-san-fran...
# 3  https://www.yelp.com/biz/brasserie-saint-james...
# 4   https://www.yelp.com/biz/matador-san-francisco-2

# %%
a
# Out:
# 'https://www.yelp.com/biz/j%C5%AB-ni-san-francisco-5'

# %%
a = restaurant_url_df["restaurant_url"][0]

# %%
response = requests.get(a)
dom = BeautifulSoup(response.content, "html.parser")
review_elements = dom.select('div.review-content')

# %%
for review_element in review_elements:
    review= review_element.select_one('p').text
    print(review)
# Out:
# Geoffrey was our chef and he was great - he knew his fish and explained everything well. Also very friendly.The omakase was incredible and great fish quality (comes from Japan woohoo!). My friend and I both got the additional supplement (wagyu with black truffle, chu-toro with uni and kaisui uni for $34). I mean, if you're already cashing in for omakase, what's $34...haha. My favorite piece of the omakase was the ikura with shaved frozen akimo on top. AMAZING. My other favorite was the kaisui uni. Seriously - butter of the sea.This omakase experience seems to be very much about exploring new things/trying to do something different with the sushi - lots of torching and different sauces/curing/marinating. Unique and deliciousThe interior of the restaurant is clean and modern, I'd even go with trendy. Staff was very friendly and attentive. Note: $$$$ but worth it if you're into sushi!!
# ...

# %%
b = "http://www.yelp.com/biz/hey-cookie-san-francisco"
response1=requests.get(b)
dom1 = BeautifulSoup(response1.content, "html.parser")
review_elements = dom1.select('div.review-content')
for review_element in review_elements:
    good_review= review_element.select_one('p').text
    print(good_review)
# Out:
# Don't settle for imitations. Christa is the best.
# On my most recent visit to the now re-opened and revitalized Dolores Park, I could not help my eyes as they wandered over the huge mass of people out that day in the hopes of seeing an adorable dirndl wearing and basket carrying women with an abundance of sweet treats! Alas all I saw was the coconut cooler guy...I still recall the first time I saw her there, advising us of her non-weed cookies! Phew, boy was I sure relieved! The cookies were flat and crisp around the edges with a little chew in the middle, absolutely scrummy. Rice crispy treat weren't what I would go for, but that's more of me being partial to the ones I make at home.All in allGreat Cookies! Great Attitude and Great Prices!
# Wowzers Silly gooses I found some great cookies at this establishment... The sugar cookies with cinnamon swirls were real rascals. Great place!
# ...

# %%
restaurant_name = dom1.select_one('h1.biz-page-title.embossed-text-white.shortenough').text

# %%
restaurant_name.replace('\n','')
# Out:
# u'        Hey, Cookie!    '

# %%
type(response1)
# Out:
# requests.models.Response

# %%
#href_df = pd.DataFrame(columns=["restaurant_href"])
    
#for numbers in range(0,55):
 #   href_numbers = df_restaurant_raw.restaurant_href[numbers].get('href')
      #  href_df.loc[len(href_df)] = [href_numbers]

#new_href_df=href_df.drop([0,11,22,33,44])
#new_href_df

#new_href_df.index=range(0,50)
#new_href_df

for i in range(0,50):
    if i <50:
        response_i = requests.get("https://www.yelp.com/{item}".format(item=new_href_df.restaurant_href[i]))
#     response_1=requests.get("https://www.yelp.com/{item}".format(item=new_href_df.restaurant_href[i]))
        dom = BeautifulSoup(response_i.content, "html.parser")
    print(dom)
    
#     dom = BeautifulSoup(response_1.content, "html.parser")
#     review_elements = dom.select('div.column.column-alpha.main-section')
    #review_elements= dom.select('p')
    #reviewer_elements = dom.select('li.user-name')
#     reviewer_elements = dom.select('div.media-story')
#     reviewer_elements
#     print(reviewer_elements) #여기서 이름만 긁을 수 있는 방법?
# Out:
# <!DOCTYPE HTML>
#
# <!--[if lt IE 7 ]> <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie6 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie7 ie ltie9 ltie8 no-js" lang="en"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie8 ie ltie9 no-js" lang="en"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns:fb="http://www.facebook.com/2008/fbml" class="ie9 ie no-js" lang="en"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--> <html class="no-js" lang="en" xmlns:fb="http://www.facebook.com/2008/fbml"> <!--<![endif]-->
# <head>
# <script type="text/javascript">
#             window.yPageStart = new Date().getTime();
#
#
# </script>
# <script type="text/javascript">
#             var initialVisibilityState = document.webkitVisibilityState;
#
#                 yPerfTimings = [];
#
# ...

# %%
response = requests.get("https://www.yelp.com/biz/hey-cookie-san-francisco?start=20")
response
# Out:
# <Response [200]>

# %%
dom  = BeautifulSoup(response.content, "html.parser")
review_elements = dom.select('div.column.column-alpha.main-section')
#review_elements= dom.select('p')
#reviewer_elements = dom.select('li.user-name')
reviewer_elements = dom.select('div.media-story')
reviewer_elements
print(reviewer_elements) #여기서 이름만 긁을 수 있는 방법?
# Out:
# [<div class="media-story">\n<div class="media-title">\n<a class="biz-name" data-hovercard-id="w70WzIcgoAFEwppS3fEqlw" href="/biz/hey-cookie-san-francisco"><span>Hey, Cookie!</span></a>\n</div>\n<address>\n        San Francisco, CA\n    </address>\n</div>, <div class="media-story">\n<a class="photo-desc" href="/biz_photos/hey-cookie-san-francisco?select=IggZC04WC-APXWkCE9ddGw">\n                Hey, Cookie! - San Francisco, CA, United States\n            </a>\n<span class="author">\n                by         <a class="user-display-name" data-hovercard-id="XgpM4XqXCceLE3fZOYnXLg" href="/user_details?userid=NxWc7U9n77P9qvVUa4ZKXA">Christa H.</a>\n</span>\n</div>, <div class="media-story">\n<a class="photo-desc" href="/biz_photos/hey-cookie-san-francisco?select=YxnexG8SwdQ4RXqTP7q9MA">\n                Hey, Cookie! - San Francisco, CA, United States\n            </a>\n<span class="author">\n                by         <a class="user-display-name" data-hovercard-id="XgpM4XqXCceLE3fZOYnXLg
# ...

# %%
for reviewer_element in reviewer_elements:
    user_href=reviewer_element.select('a').get('href') #select_one('a.user-display-name').attrs.get('href')는 none값이 섞여서 에러가나요
    print(user_href)
    #attrs =reviewer_element.select('li.user-name')
    attrs_2 = reviewer_element.select('ul.user-passport-stats')
    
    for friend_number in attrs_2:
        #friends_number = friend_number.select_one('span').text
        friends_number = friend_number.select('span')[0].text
        reviews_number = friend_number.select('span')[1].text
        #print(friends_number)
    #print(rate)
    #for name in attrs:
        #user_name=user.text
    
    
    
#     user_name = 

for review_element in review_elements:
    review = review_element.select().text
    # print(review)
            
    
    
#rating = review_info.get('title')
# Out:
# /biz/hey-cookie-san-francisco
# /biz_photos/hey-cookie-san-francisco?select=Fm06mF6L1gj4PVFVubGi6A
# /biz_photos/hey-cookie-san-francisco?select=DrRfOag9o3XvvRAL-N2N_A
# http://www.yelp.com/biz/hey-cookie-san-francisco?hrid=dnospgDcAZifi3WPI91j9Q&rh_ident=christa&rh_type=phrase
# http://www.yelp.com/biz/hey-cookie-san-francisco?hrid=8LLj7f9-1pY-7rAgXXzb6g&rh_ident=brownie&rh_type=phrase
# http://www.yelp.com/biz/hey-cookie-san-francisco?hrid=Rr74i-0V5wgvKWZn4OV3vA&rh_ident=gluten&rh_type=phrase
# /user_details?userid=t5PRz_9oFr9Qm6JRjMXwnQ
# /user_details?userid=am2UDS4eHmL99dEDzUVeSQ
# /user_details?userid=lHnMp5AxsBHyky2RG238Uw
# /user_details?userid=4tCR-W-Vc3v7iuB_aySYKg
# /user_details?userid=_Idq3K3_H6_m0I9s-1q_fg
# /user_details?userid=THpVHfXQ2LEroI96xAe-_Q
# /user_details?userid=l2uNHbNrt6dmW7PNklJRdg
# /user_details?userid=6JcNjASZEfQ1g6meSCZ9Pw
# /user_details?userid=OMoBzr4FhDkk7yV8zYtmiw
# /user_details?userid=-53wuLdpIWGQqiEsfXlcxg
# ...
